# %%
import basedosdados as bd
from dotenv import load_dotenv
import os

load_dotenv()

billing_id = os.getenv("BILLING_ID")

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf as sigla_uf,
    dados.id_regiao as id_regiao,
    dados.id_municipio as id_municipio,
    dados.area as area,
    dados.mascara as mascara,
    dados.ano_mascara as ano_mascara,
    dados.id_escola as id_escola,
    dados.rede as rede,
    dados.escola_publica as escola_publica,
    dados.localizacao as localizacao,
    dados.id_turma as id_turma,
    dados.turno as turno,
    dados.serie as serie,
    dados.id_aluno as id_aluno,
    dados.situacao_censo as situacao_censo,
    dados.disciplina as disciplina,
    dados.preenchimento_caderno as preenchimento_caderno,
    dados.presenca as presenca,
    dados.caderno as caderno,
    dados.bloco_1 as bloco_1,
    dados.bloco_2 as bloco_2,
    dados.bloco_3 as bloco_3,
    dados.bloco_1_aberto as bloco_1_aberto,
    dados.bloco_2_aberto as bloco_2_aberto,
    dados.respostas_bloco_1 as respostas_bloco_1,
    dados.respostas_bloco_2 as respostas_bloco_2,
    dados.respostas_bloco_3 as respostas_bloco_3,
    dados.conceito_q1 as conceito_q1,
    dados.conceito_q2 as conceito_q2,
    dados.gabarito_bloco_1 as gabarito_bloco_1,
    dados.gabarito_bloco_2 as gabarito_bloco_2,
    dados.gabarito_bloco_3 as gabarito_bloco_3,
    dados.indicador_proficiencia as indicador_proficiencia,
    dados.indicador_prova_brasil as indicador_prova_brasil,
    dados.amostra as amostra,
    dados.estrato as estrato,
    dados.peso_escola as peso_escola,
    dados.peso_turma as peso_turma,
    dados.peso_aluno_turma as peso_aluno_turma,
    dados.peso_aluno as peso_aluno,
    dados.proficiencia as proficiencia,
    dados.erro_padrao as erro_padrao,
    dados.proficiencia_saeb as proficiencia_saeb,
    dados.erro_padrao_saeb as erro_padrao_saeb,
    dados.desempenho_aluno as desempenho_aluno,
    dados.preenchimento_questionario as preenchimento_questionario,
    dados.sexo as sexo,
    dados.raca_cor as raca_cor,
    dados.mes_nascimento as mes_nascimento,
    dados.ano_nascimento as ano_nascimento,
    dados.idade as idade,
    dados.faixa_etaria as faixa_etaria,
    dados.possui_necessidade_especial as possui_necessidade_especial,
    dados.estado_civil as estado_civil,
    dados.possui_filhos as possui_filhos,
    dados.com_quem_mora as com_quem_mora,
    dados.mora_mae as mora_mae,
    dados.mora_pai as mora_pai,
    dados.mora_irmaos as mora_irmaos,
    dados.mora_avos as mora_avos,
    dados.mora_conjuge as mora_conjuge,
    dados.mora_filhos as mora_filhos,
    dados.mora_outros_parentes as mora_outros_parentes,
    dados.mora_amigos as mora_amigos,
    dados.idioma_domicilio as idioma_domicilio,
    dados.quantidade_pessoas_domicilio as quantidade_pessoas_domicilio,
    dados.quantidade_pessoas_despesas_domicilio as quantidade_pessoas_despesas_domicilio,
    dados.situacao_economica as situacao_economica,
    dados.possui_trabalho as possui_trabalho,
    dados.turma_bolsa_escola as turma_bolsa_escola,
    dados.aluno_bolsa_escola as aluno_bolsa_escola,
    dados.indicador_inse as indicador_inse,
    dados.inse as inse,
    dados.nivel_inse as nivel_inse,
    dados.peso_inse as peso_inse,
    dados.possui_moradia_rua_urbanizada as possui_moradia_rua_urbanizada,
    dados.possui_agua_encanada as possui_agua_encanada,
    dados.possui_eletrecidade as possui_eletrecidade,
    dados.possui_eletrodomestico_sem_eletricidade as possui_eletrodomestico_sem_eletricidade,
    dados.possui_casa_dormitorio as possui_casa_dormitorio,
    dados.possui_casa_quarto_individual as possui_casa_quarto_individual,
    dados.possui_casa_cozinha as possui_casa_cozinha,
    dados.possui_casa_banheiro as possui_casa_banheiro,
    dados.possui_casa_sala as possui_casa_sala,
    dados.possui_automovel as possui_automovel,
    dados.possui_casa_garagem as possui_casa_garagem,
    dados.possui_geladeira as possui_geladeira,
    dados.possui_geladeira_freezer as possui_geladeira_freezer,
    dados.possui_freezer as possui_freezer,
    dados.possui_microondas as possui_microondas,
    dados.possui_maquina_lavar_roupa as possui_maquina_lavar_roupa,
    dados.possui_aspirador_po as possui_aspirador_po,
    dados.possui_radio as possui_radio,
    dados.possui_tv as possui_tv,
    dados.possui_tv_assinatura as possui_tv_assinatura,
    dados.possui_videocassete_dvd as possui_videocassete_dvd,
    dados.possui_internet as possui_internet,
    dados.possui_computador as possui_computador,
    dados.possui_computador_sem_internet as possui_computador_sem_internet,
    dados.possui_tablet as possui_tablet,
    dados.possui_telefone as possui_telefone,
    dados.possui_celular as possui_celular,
    dados.possui_escrivaninha as possui_escrivaninha,
    dados.possui_enciclopedia as possui_enciclopedia,
    dados.possui_atlas as possui_atlas,
    dados.possui_dicionario as possui_dicionario,
    dados.possui_calculadora as possui_calculadora,
    dados.possui_empregada_domestica as possui_empregada_domestica,
    dados.possui_empregada_domestica_cinco_dias as possui_empregada_domestica_cinco_dias,
    dados.escolaridade_mae as escolaridade_mae,
    dados.mae_sabe_ler_escrever as mae_sabe_ler_escrever,
    dados.mae_le as mae_le,
    dados.ocupacao_mae as ocupacao_mae,
    dados.escolaridade_pai as escolaridade_pai,
    dados.pai_sabe_ler_escrever as pai_sabe_ler_escrever,
    dados.pai_le as pai_le,
    dados.ocupacao_pai as ocupacao_pai,
    dados.pessoa_acompanha_vida_escolar as pessoa_acompanha_vida_escolar,
    dados.escolaridade_pessoa as escolaridade_pessoa,
    dados.responsaveis_conhecem_diretor as responsaveis_conhecem_diretor,
    dados.responsaveis_conhecem_professor as responsaveis_conhecem_professor,
    dados.responsaveis_conversam_professor_diretor as responsaveis_conversam_professor_diretor,
    dados.responsaveis_conversam_diretor as responsaveis_conversam_diretor,
    dados.responsaveis_conversam_professor as responsaveis_conversam_professor,
    dados.responsaveis_conhecem_amigo as responsaveis_conhecem_amigo,
    dados.responsaveis_conhecem_responsavel_amigo as responsaveis_conhecem_responsavel_amigo,
    dados.responsaveis_leem as responsaveis_leem,
    dados.responsaveis_almocam_jantam_contigo as responsaveis_almocam_jantam_contigo,
    dados.responsaveis_ouvem_musica_contigo as responsaveis_ouvem_musica_contigo,
    dados.responsaveis_conversam_livros_contigo as responsaveis_conversam_livros_contigo,
    dados.responsaveis_conversam_filmes_contigo as responsaveis_conversam_filmes_contigo,
    dados.responsaveis_conversam_programas_tv_contigo as responsaveis_conversam_programas_tv_contigo,
    dados.responsaveis_conversam_amigos as responsaveis_conversam_amigos,
    dados.responsaveis_conversam_amigos_escola as responsaveis_conversam_amigos_escola,
    dados.responsaveis_conversam_responsaveis_amigo as responsaveis_conversam_responsaveis_amigo,
    dados.responsaveis_conversam_outros_assuntos_contigo as responsaveis_conversam_outros_assuntos_contigo,
    dados.responsaveis_conversam_escola as responsaveis_conversam_escola,
    dados.responsaveis_conversam_boletim as responsaveis_conversam_boletim,
    dados.responsaveis_conversam_comportamento as responsaveis_conversam_comportamento,
    dados.responsaveis_cobram_realizacao_tarefa_casa as responsaveis_cobram_realizacao_tarefa_casa,
    dados.responsaveis_ajudam_realizacao_tarefa_casa as responsaveis_ajudam_realizacao_tarefa_casa,
    dados.responsaveis_incentivam_realizacao_licao_casa as responsaveis_incentivam_realizacao_licao_casa,
    dados.responsaveis_incentivam_estudos as responsaveis_incentivam_estudos,
    dados.responsaveis_incentivam_leitura as responsaveis_incentivam_leitura,
    dados.responsaveis_incentivam_comparecer_aulas as responsaveis_incentivam_comparecer_aulas,
    dados.responsaveis_incentivam_pontualidade as responsaveis_incentivam_pontualidade,
    dados.responsaveis_incentivam_boas_notas as responsaveis_incentivam_boas_notas,
    dados.responsaveis_comparecem_reuniao_pais as responsaveis_comparecem_reuniao_pais,
    dados.responsaveis_participam_festas_escola as responsaveis_participam_festas_escola,
    dados.responsaveis_participam_trabalho_voluntario as responsaveis_participam_trabalho_voluntario,
    dados.tempo_chegada_escola as tempo_chegada_escola,
    dados.forma_chegada_escola as forma_chegada_escola,
    dados.transporte_escolar as transporte_escolar,
    dados.inicio_estudos as inicio_estudos,
    dados.quantos_anos_primeiro_grau as quantos_anos_primeiro_grau,
    dados.quantos_anos_segundo_grau as quantos_anos_segundo_grau,
    dados.idade_entrada_escola as idade_entrada_escola,
    dados.quantidade_mudancas_escola as quantidade_mudancas_escola,
    dados.presenca_professor as presenca_professor,
    dados.supletivo_ef as supletivo_ef,
    dados.rede_ef as rede_ef,
    dados.reprovacao as reprovacao,
    dados.evasao_escolar_ate_final_ano as evasao_escolar_ate_final_ano,
    dados.evasao_escolar_temporaria as evasao_escolar_temporaria,
    dados.motivo_evasao_escolar as motivo_evasao_escolar,
    dados.faltas_aula as faltas_aula,
    dados.motivo_faltas as motivo_faltas,
    dados.desempenho_prejudicado_falta as desempenho_prejudicado_falta,
    dados.tempo_lazer as tempo_lazer,
    dados.tipo_programacao_tv as tipo_programacao_tv,
    dados.tempo_cursos as tempo_cursos,
    dados.tempo_trabalho_domestico as tempo_trabalho_domestico,
    dados.tempo_estudos as tempo_estudos,
    dados.quantidade_livros as quantidade_livros,
    dados.recebe_jornais as recebe_jornais,
    dados.recebe_revistas as recebe_revistas,
    dados.leitura_jornais as leitura_jornais,
    dados.leitura_noticias as leitura_noticias,
    dados.leitura_livros_geral as leitura_livros_geral,
    dados.leitura_literatura as leitura_literatura,
    dados.leitura_literatura_infantojuvenil as leitura_literatura_infantojuvenil,
    dados.leitura_historia_quadrinhos as leitura_historia_quadrinhos,
    dados.leitura_revistas_tematicas as leitura_revistas_tematicas,
    dados.leitura_revista_comportamento as leitura_revista_comportamento,
    dados.leitura_revistas_geral as leitura_revistas_geral,
    dados.leitura_internet as leitura_internet,
    dados.leitura_outros_materiais as leitura_outros_materiais,
    dados.frequenta_biblioteca as frequenta_biblioteca,
    dados.frequenta_cinema as frequenta_cinema,
    dados.frequenta_espetaculo_exposicao as frequenta_espetaculo_exposicao,
    dados.frequenta_teatro as frequenta_teatro,
    dados.frequenta_show as frequenta_show,
    dados.frequenta_festas_comunidade as frequenta_festas_comunidade,
    dados.participa_gremio_escolar as participa_gremio_escolar,
    dados.participa_associacao_desportiva as participa_associacao_desportiva,
    dados.participa_associacao_moradores as participa_associacao_moradores,
    dados.participa_sindicato as participa_sindicato,
    dados.participa_movimento_religioso as participa_movimento_religioso,
    dados.participa_partido_politico as participa_partido_politico,
    dados.participa_ong as participa_ong,
    dados.nao_participa as nao_participa,
    dados.participa_atividades_esporte as participa_atividades_esporte,
    dados.participa_atividades_artisticas as participa_atividades_artisticas,
    dados.participa_trabalho_solidario as participa_trabalho_solidario,
    dados.participa_reforco_escolar as participa_reforco_escolar,
    dados.participa_excursao_acampamento as participa_excursao_acampamento,
    dados.participa_festas as participa_festas,
    dados.curso_atividades_artisticas as curso_atividades_artisticas,
    dados.curso_reforco_escolar as curso_reforco_escolar,
    dados.curso_idioma_externo as curso_idioma_externo,
    dados.curso_informatica as curso_informatica,
    dados.curso_outros as curso_outros,
    dados.quando_nao_entende_materia as quando_nao_entende_materia,
    dados.gosta_estudar_disciplina as gosta_estudar_disciplina,
    dados.entendimento_ensino as entendimento_ensino,
    dados.disciplina_auxilia_compreensao as disciplina_auxilia_compreensao,
    dados.professor_disciplina as professor_disciplina,
    dados.faz_licao_casa as faz_licao_casa,
    dados.tempo_licao_casa as tempo_licao_casa,
    dados.fez_redacao as fez_redacao,
    dados.professor_leitura_livros_licao_casa as professor_leitura_livros_licao_casa,
    dados.correcao_licao_casa as correcao_licao_casa,
    dados.correcao_licao_casa_alunos as correcao_licao_casa_alunos,
    dados.consulta_jornais_revistas_licao_casa as consulta_jornais_revistas_licao_casa,
    dados.utiliza_computador_licao_casa as utiliza_computador_licao_casa,
    dados.utiliza_computador as utiliza_computador,
    dados.utiliza_computador_escola as utiliza_computador_escola,
    dados.utiliza_biblioteca_escola as utiliza_biblioteca_escola,
    dados.utiliza_biblioteca_externa as utiliza_biblioteca_externa,
    dados.existe_lugar_calmo_estudos as existe_lugar_calmo_estudos,
    dados.comparacao_colegas_disciplina as comparacao_colegas_disciplina,
    dados.boas_notas_disciplina as boas_notas_disciplina,
    dados.desempenho_disciplina as desempenho_disciplina,
    dados.professor_importa_voce_diz as professor_importa_voce_diz,
    dados.professor_conversa_avaliacao as professor_conversa_avaliacao,
    dados.professor_elogia_merecimento as professor_elogia_merecimento,
    dados.professor_ajuda_se_necessario as professor_ajuda_se_necessario,
    dados.professor_atende_prontamente as professor_atende_prontamente,
    dados.professor_esforca_aprendizado as professor_esforca_aprendizado,
    dados.professor_utiliza_espacos_externos as professor_utiliza_espacos_externos,
    dados.professor_espera_silencio as professor_espera_silencio,
    dados.professor_cobra as professor_cobra,
    dados.brigou_professor as brigou_professor,
    dados.turma_exclui as turma_exclui,
    dados.familia_avisada_falta as familia_avisada_falta,
    dados.alunos_desordeiros as alunos_desordeiros,
    dados.alunos_atentos as alunos_atentos,
    dados.alunos_obedientes as alunos_obedientes,
    dados.possui_amigos_sala as possui_amigos_sala,
    dados.estuda_habitualmente as estuda_habitualmente,
    dados.motivo_estar_escola as motivo_estar_escola,
    dados.utiliza_aprendizado_diariamente as utiliza_aprendizado_diariamente,
    dados.pandemia_equipamento_ensino_remoto as pandemia_equipamento_ensino_remoto,
    dados.pandemia_internet_ensino_remoto as pandemia_internet_ensino_remoto,
    dados.pandemia_facilidade_programas as pandemia_facilidade_programas,
    dados.pandemia_recebeu_material as pandemia_recebeu_material,
    dados.pandemia_auxilio_professor as pandemia_auxilio_professor,
    dados.pandemia_compreensao_conteudo as pandemia_compreensao_conteudo,
    dados.pandemia_ambiente_tranquilo as pandemia_ambiente_tranquilo,
    dados.pandemia_apoio_familia as pandemia_apoio_familia,
    dados.pandemia_apoio_colegas as pandemia_apoio_colegas,
    dados.pretensao_futura as pretensao_futura,
    dados.opiniao_teste as opiniao_teste,
    dados.opiniao_frase_1 as opiniao_frase_1,
    dados.opiniao_frase_2 as opiniao_frase_2,
    dados.opiniao_frase_3 as opiniao_frase_3
FROM `basedosdados.br_inep_saeb.aluno_ef_9ano` AS dados
WHERE dados.sigla_uf = 'PB' AND dados.preenchimento_caderno = 1 AND dados.presenca = 1;
"""

bd.read_sql(query = query, billing_project_id = billing_id)
# Out:
# Downloading: 100%|██████████| 156515/156515 [03:56<00:00, 662.37rows/s]
#          ano sigla_uf id_regiao id_municipio area mascara  ano_mascara  \
# 0       2021       PB         2      6317893    2    None         <NA>
# 1       2021       PB         2      6318060    2    None         <NA>
# 2       2021       PB         2      6317937    1    None         <NA>
# 3       2021       PB         2      6317925    2    None         <NA>
# 4       2021       PB         2      6318016    2    None         <NA>
# ...      ...      ...       ...          ...  ...     ...          ...
# 156510  2019       PB         2      2500700    2    None         <NA>
# 156511  2019       PB         2      2504009    2    None         <NA>
# 156512  2019       PB         2      2504009    2    None         <NA>
# 156513  2019       PB         2      2516003    2    None         <NA>
# 156514  2019       PB         2      2516201    2    None         <NA>
#
# ...

# %%
_oh[1].to_pickle('saeb_pb.pkl')

# %%
import pandas as pd
df = pd.read_pickle('saeb_pb.pkl')
df['ano'].unique()
# Out:
# <IntegerArray>
# [2021, 2019]
# Length: 2, dtype: Int64

# %%
import basedosdados as bd
from dotenv import load_dotenv
import os

load_dotenv()

billing_id = os.getenv("BILLING_ID")

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf as sigla_uf,
    dados.id_regiao as id_regiao,
    dados.id_municipio as id_municipio,
    dados.area as area,
    dados.mascara as mascara,
    dados.ano_mascara as ano_mascara,
    dados.id_escola as id_escola,
    dados.rede as rede,
    dados.escola_publica as escola_publica,
    dados.localizacao as localizacao,
    dados.id_turma as id_turma,
    dados.turno as turno,
    dados.serie as serie,
    dados.id_aluno as id_aluno,
    dados.situacao_censo as situacao_censo,
    dados.disciplina as disciplina,
    dados.preenchimento_caderno as preenchimento_caderno,
    dados.presenca as presenca,
    dados.caderno as caderno,
    dados.bloco_1 as bloco_1,
    dados.bloco_2 as bloco_2,
    dados.bloco_3 as bloco_3,
    dados.bloco_1_aberto as bloco_1_aberto,
    dados.bloco_2_aberto as bloco_2_aberto,
    dados.respostas_bloco_1 as respostas_bloco_1,
    dados.respostas_bloco_2 as respostas_bloco_2,
    dados.respostas_bloco_3 as respostas_bloco_3,
    dados.conceito_q1 as conceito_q1,
    dados.conceito_q2 as conceito_q2,
    dados.gabarito_bloco_1 as gabarito_bloco_1,
    dados.gabarito_bloco_2 as gabarito_bloco_2,
    dados.gabarito_bloco_3 as gabarito_bloco_3,
    dados.indicador_proficiencia as indicador_proficiencia,
    dados.indicador_prova_brasil as indicador_prova_brasil,
    dados.amostra as amostra,
    dados.estrato as estrato,
    dados.peso_escola as peso_escola,
    dados.peso_turma as peso_turma,
    dados.peso_aluno_turma as peso_aluno_turma,
    dados.peso_aluno as peso_aluno,
    dados.proficiencia as proficiencia,
    dados.erro_padrao as erro_padrao,
    dados.proficiencia_saeb as proficiencia_saeb,
    dados.erro_padrao_saeb as erro_padrao_saeb,
    dados.desempenho_aluno as desempenho_aluno,
    dados.preenchimento_questionario as preenchimento_questionario,
    dados.sexo as sexo,
    dados.raca_cor as raca_cor,
    dados.mes_nascimento as mes_nascimento,
    dados.ano_nascimento as ano_nascimento,
    dados.idade as idade,
    dados.faixa_etaria as faixa_etaria,
    dados.possui_necessidade_especial as possui_necessidade_especial,
    dados.estado_civil as estado_civil,
    dados.possui_filhos as possui_filhos,
    dados.com_quem_mora as com_quem_mora,
    dados.mora_mae as mora_mae,
    dados.mora_pai as mora_pai,
    dados.mora_irmaos as mora_irmaos,
    dados.mora_avos as mora_avos,
    dados.mora_conjuge as mora_conjuge,
    dados.mora_filhos as mora_filhos,
    dados.mora_outros_parentes as mora_outros_parentes,
    dados.mora_amigos as mora_amigos,
    dados.idioma_domicilio as idioma_domicilio,
    dados.quantidade_pessoas_domicilio as quantidade_pessoas_domicilio,
    dados.quantidade_pessoas_despesas_domicilio as quantidade_pessoas_despesas_domicilio,
    dados.situacao_economica as situacao_economica,
    dados.possui_trabalho as possui_trabalho,
    dados.turma_bolsa_escola as turma_bolsa_escola,
    dados.aluno_bolsa_escola as aluno_bolsa_escola,
    dados.indicador_inse as indicador_inse,
    dados.inse as inse,
    dados.nivel_inse as nivel_inse,
    dados.peso_inse as peso_inse,
    dados.possui_moradia_rua_urbanizada as possui_moradia_rua_urbanizada,
    dados.possui_agua_encanada as possui_agua_encanada,
    dados.possui_eletrecidade as possui_eletrecidade,
    dados.possui_eletrodomestico_sem_eletricidade as possui_eletrodomestico_sem_eletricidade,
    dados.possui_casa_dormitorio as possui_casa_dormitorio,
    dados.possui_casa_quarto_individual as possui_casa_quarto_individual,
    dados.possui_casa_cozinha as possui_casa_cozinha,
    dados.possui_casa_banheiro as possui_casa_banheiro,
    dados.possui_casa_sala as possui_casa_sala,
    dados.possui_automovel as possui_automovel,
    dados.possui_casa_garagem as possui_casa_garagem,
    dados.possui_geladeira as possui_geladeira,
    dados.possui_geladeira_freezer as possui_geladeira_freezer,
    dados.possui_freezer as possui_freezer,
    dados.possui_microondas as possui_microondas,
    dados.possui_maquina_lavar_roupa as possui_maquina_lavar_roupa,
    dados.possui_aspirador_po as possui_aspirador_po,
    dados.possui_radio as possui_radio,
    dados.possui_tv as possui_tv,
    dados.possui_tv_assinatura as possui_tv_assinatura,
    dados.possui_videocassete_dvd as possui_videocassete_dvd,
    dados.possui_internet as possui_internet,
    dados.possui_computador as possui_computador,
    dados.possui_computador_sem_internet as possui_computador_sem_internet,
    dados.possui_tablet as possui_tablet,
    dados.possui_telefone as possui_telefone,
    dados.possui_celular as possui_celular,
    dados.possui_escrivaninha as possui_escrivaninha,
    dados.possui_enciclopedia as possui_enciclopedia,
    dados.possui_atlas as possui_atlas,
    dados.possui_dicionario as possui_dicionario,
    dados.possui_calculadora as possui_calculadora,
    dados.possui_empregada_domestica as possui_empregada_domestica,
    dados.possui_empregada_domestica_cinco_dias as possui_empregada_domestica_cinco_dias,
    dados.escolaridade_mae as escolaridade_mae,
    dados.mae_sabe_ler_escrever as mae_sabe_ler_escrever,
    dados.mae_le as mae_le,
    dados.ocupacao_mae as ocupacao_mae,
    dados.escolaridade_pai as escolaridade_pai,
    dados.pai_sabe_ler_escrever as pai_sabe_ler_escrever,
    dados.pai_le as pai_le,
    dados.ocupacao_pai as ocupacao_pai,
    dados.pessoa_acompanha_vida_escolar as pessoa_acompanha_vida_escolar,
    dados.escolaridade_pessoa as escolaridade_pessoa,
    dados.responsaveis_conhecem_diretor as responsaveis_conhecem_diretor,
    dados.responsaveis_conhecem_professor as responsaveis_conhecem_professor,
    dados.responsaveis_conversam_professor_diretor as responsaveis_conversam_professor_diretor,
    dados.responsaveis_conversam_diretor as responsaveis_conversam_diretor,
    dados.responsaveis_conversam_professor as responsaveis_conversam_professor,
    dados.responsaveis_conhecem_amigo as responsaveis_conhecem_amigo,
    dados.responsaveis_conhecem_responsavel_amigo as responsaveis_conhecem_responsavel_amigo,
    dados.responsaveis_leem as responsaveis_leem,
    dados.responsaveis_almocam_jantam_contigo as responsaveis_almocam_jantam_contigo,
    dados.responsaveis_ouvem_musica_contigo as responsaveis_ouvem_musica_contigo,
    dados.responsaveis_conversam_livros_contigo as responsaveis_conversam_livros_contigo,
    dados.responsaveis_conversam_filmes_contigo as responsaveis_conversam_filmes_contigo,
    dados.responsaveis_conversam_programas_tv_contigo as responsaveis_conversam_programas_tv_contigo,
    dados.responsaveis_conversam_amigos as responsaveis_conversam_amigos,
    dados.responsaveis_conversam_amigos_escola as responsaveis_conversam_amigos_escola,
    dados.responsaveis_conversam_responsaveis_amigo as responsaveis_conversam_responsaveis_amigo,
    dados.responsaveis_conversam_outros_assuntos_contigo as responsaveis_conversam_outros_assuntos_contigo,
    dados.responsaveis_conversam_escola as responsaveis_conversam_escola,
    dados.responsaveis_conversam_boletim as responsaveis_conversam_boletim,
    dados.responsaveis_conversam_comportamento as responsaveis_conversam_comportamento,
    dados.responsaveis_cobram_realizacao_tarefa_casa as responsaveis_cobram_realizacao_tarefa_casa,
    dados.responsaveis_ajudam_realizacao_tarefa_casa as responsaveis_ajudam_realizacao_tarefa_casa,
    dados.responsaveis_incentivam_realizacao_licao_casa as responsaveis_incentivam_realizacao_licao_casa,
    dados.responsaveis_incentivam_estudos as responsaveis_incentivam_estudos,
    dados.responsaveis_incentivam_leitura as responsaveis_incentivam_leitura,
    dados.responsaveis_incentivam_comparecer_aulas as responsaveis_incentivam_comparecer_aulas,
    dados.responsaveis_incentivam_pontualidade as responsaveis_incentivam_pontualidade,
    dados.responsaveis_incentivam_boas_notas as responsaveis_incentivam_boas_notas,
    dados.responsaveis_comparecem_reuniao_pais as responsaveis_comparecem_reuniao_pais,
    dados.responsaveis_participam_festas_escola as responsaveis_participam_festas_escola,
    dados.responsaveis_participam_trabalho_voluntario as responsaveis_participam_trabalho_voluntario,
    dados.tempo_chegada_escola as tempo_chegada_escola,
    dados.forma_chegada_escola as forma_chegada_escola,
    dados.transporte_escolar as transporte_escolar,
    dados.inicio_estudos as inicio_estudos,
    dados.quantos_anos_primeiro_grau as quantos_anos_primeiro_grau,
    dados.quantos_anos_segundo_grau as quantos_anos_segundo_grau,
    dados.idade_entrada_escola as idade_entrada_escola,
    dados.quantidade_mudancas_escola as quantidade_mudancas_escola,
    dados.presenca_professor as presenca_professor,
    dados.supletivo_ef as supletivo_ef,
    dados.rede_ef as rede_ef,
    dados.reprovacao as reprovacao,
    dados.evasao_escolar_ate_final_ano as evasao_escolar_ate_final_ano,
    dados.evasao_escolar_temporaria as evasao_escolar_temporaria,
    dados.motivo_evasao_escolar as motivo_evasao_escolar,
    dados.faltas_aula as faltas_aula,
    dados.motivo_faltas as motivo_faltas,
    dados.desempenho_prejudicado_falta as desempenho_prejudicado_falta,
    dados.tempo_lazer as tempo_lazer,
    dados.tipo_programacao_tv as tipo_programacao_tv,
    dados.tempo_cursos as tempo_cursos,
    dados.tempo_trabalho_domestico as tempo_trabalho_domestico,
    dados.tempo_estudos as tempo_estudos,
    dados.quantidade_livros as quantidade_livros,
    dados.recebe_jornais as recebe_jornais,
    dados.recebe_revistas as recebe_revistas,
    dados.leitura_jornais as leitura_jornais,
    dados.leitura_noticias as leitura_noticias,
    dados.leitura_livros_geral as leitura_livros_geral,
    dados.leitura_literatura as leitura_literatura,
    dados.leitura_literatura_infantojuvenil as leitura_literatura_infantojuvenil,
    dados.leitura_historia_quadrinhos as leitura_historia_quadrinhos,
    dados.leitura_revistas_tematicas as leitura_revistas_tematicas,
    dados.leitura_revista_comportamento as leitura_revista_comportamento,
    dados.leitura_revistas_geral as leitura_revistas_geral,
    dados.leitura_internet as leitura_internet,
    dados.leitura_outros_materiais as leitura_outros_materiais,
    dados.frequenta_biblioteca as frequenta_biblioteca,
    dados.frequenta_cinema as frequenta_cinema,
    dados.frequenta_espetaculo_exposicao as frequenta_espetaculo_exposicao,
    dados.frequenta_teatro as frequenta_teatro,
    dados.frequenta_show as frequenta_show,
    dados.frequenta_festas_comunidade as frequenta_festas_comunidade,
    dados.participa_gremio_escolar as participa_gremio_escolar,
    dados.participa_associacao_desportiva as participa_associacao_desportiva,
    dados.participa_associacao_moradores as participa_associacao_moradores,
    dados.participa_sindicato as participa_sindicato,
    dados.participa_movimento_religioso as participa_movimento_religioso,
    dados.participa_partido_politico as participa_partido_politico,
    dados.participa_ong as participa_ong,
    dados.nao_participa as nao_participa,
    dados.participa_atividades_esporte as participa_atividades_esporte,
    dados.participa_atividades_artisticas as participa_atividades_artisticas,
    dados.participa_trabalho_solidario as participa_trabalho_solidario,
    dados.participa_reforco_escolar as participa_reforco_escolar,
    dados.participa_excursao_acampamento as participa_excursao_acampamento,
    dados.participa_festas as participa_festas,
    dados.curso_atividades_artisticas as curso_atividades_artisticas,
    dados.curso_reforco_escolar as curso_reforco_escolar,
    dados.curso_idioma_externo as curso_idioma_externo,
    dados.curso_informatica as curso_informatica,
    dados.curso_outros as curso_outros,
    dados.quando_nao_entende_materia as quando_nao_entende_materia,
    dados.gosta_estudar_disciplina as gosta_estudar_disciplina,
    dados.entendimento_ensino as entendimento_ensino,
    dados.disciplina_auxilia_compreensao as disciplina_auxilia_compreensao,
    dados.professor_disciplina as professor_disciplina,
    dados.faz_licao_casa as faz_licao_casa,
    dados.tempo_licao_casa as tempo_licao_casa,
    dados.fez_redacao as fez_redacao,
    dados.professor_leitura_livros_licao_casa as professor_leitura_livros_licao_casa,
    dados.correcao_licao_casa as correcao_licao_casa,
    dados.correcao_licao_casa_alunos as correcao_licao_casa_alunos,
    dados.consulta_jornais_revistas_licao_casa as consulta_jornais_revistas_licao_casa,
    dados.utiliza_computador_licao_casa as utiliza_computador_licao_casa,
    dados.utiliza_computador as utiliza_computador,
    dados.utiliza_computador_escola as utiliza_computador_escola,
    dados.utiliza_biblioteca_escola as utiliza_biblioteca_escola,
    dados.utiliza_biblioteca_externa as utiliza_biblioteca_externa,
    dados.existe_lugar_calmo_estudos as existe_lugar_calmo_estudos,
    dados.comparacao_colegas_disciplina as comparacao_colegas_disciplina,
    dados.boas_notas_disciplina as boas_notas_disciplina,
    dados.desempenho_disciplina as desempenho_disciplina,
    dados.professor_importa_voce_diz as professor_importa_voce_diz,
    dados.professor_conversa_avaliacao as professor_conversa_avaliacao,
    dados.professor_elogia_merecimento as professor_elogia_merecimento,
    dados.professor_ajuda_se_necessario as professor_ajuda_se_necessario,
    dados.professor_atende_prontamente as professor_atende_prontamente,
    dados.professor_esforca_aprendizado as professor_esforca_aprendizado,
    dados.professor_utiliza_espacos_externos as professor_utiliza_espacos_externos,
    dados.professor_espera_silencio as professor_espera_silencio,
    dados.professor_cobra as professor_cobra,
    dados.brigou_professor as brigou_professor,
    dados.turma_exclui as turma_exclui,
    dados.familia_avisada_falta as familia_avisada_falta,
    dados.alunos_desordeiros as alunos_desordeiros,
    dados.alunos_atentos as alunos_atentos,
    dados.alunos_obedientes as alunos_obedientes,
    dados.possui_amigos_sala as possui_amigos_sala,
    dados.estuda_habitualmente as estuda_habitualmente,
    dados.motivo_estar_escola as motivo_estar_escola,
    dados.utiliza_aprendizado_diariamente as utiliza_aprendizado_diariamente,
    dados.pandemia_equipamento_ensino_remoto as pandemia_equipamento_ensino_remoto,
    dados.pandemia_internet_ensino_remoto as pandemia_internet_ensino_remoto,
    dados.pandemia_facilidade_programas as pandemia_facilidade_programas,
    dados.pandemia_recebeu_material as pandemia_recebeu_material,
    dados.pandemia_auxilio_professor as pandemia_auxilio_professor,
    dados.pandemia_compreensao_conteudo as pandemia_compreensao_conteudo,
    dados.pandemia_ambiente_tranquilo as pandemia_ambiente_tranquilo,
    dados.pandemia_apoio_familia as pandemia_apoio_familia,
    dados.pandemia_apoio_colegas as pandemia_apoio_colegas,
    dados.pretensao_futura as pretensao_futura,
    dados.opiniao_teste as opiniao_teste,
    dados.opiniao_frase_1 as opiniao_frase_1,
    dados.opiniao_frase_2 as opiniao_frase_2,
    dados.opiniao_frase_3 as opiniao_frase_3
FROM `basedosdados.br_inep_saeb.aluno_ef_9ano` AS dados
WHERE dados.sigla_uf = 'PB' AND dados.ano = 2013;
"""

data2013 = bd.read_sql(query = query, billing_project_id = billing_id)
data2013.to_pickle('saeb_pb_2013.pkl')
# Out:
# Downloading: 100%|██████████| 95170/95170 [02:15<00:00, 702.60rows/s]

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
# ...

# %%
_oh[1].to_pickle('saeb_pb_2013.pkl')

# %%
import basedosdados as bd
from dotenv import load_dotenv
import os

load_dotenv()

billing_id = os.getenv("BILLING_ID")

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf as sigla_uf,
    dados.id_regiao as id_regiao,
    dados.id_municipio as id_municipio,
    dados.area as area,
    dados.mascara as mascara,
    dados.ano_mascara as ano_mascara,
    dados.id_escola as id_escola,
    dados.rede as rede,
    dados.escola_publica as escola_publica,
    dados.localizacao as localizacao,
    dados.id_turma as id_turma,
    dados.turno as turno,
    dados.serie as serie,
    dados.id_aluno as id_aluno,
    dados.situacao_censo as situacao_censo,
    dados.disciplina as disciplina,
    dados.preenchimento_caderno as preenchimento_caderno,
    dados.presenca as presenca,
    dados.caderno as caderno,
    dados.bloco_1 as bloco_1,
    dados.bloco_2 as bloco_2,
    dados.bloco_3 as bloco_3,
    dados.bloco_1_aberto as bloco_1_aberto,
    dados.bloco_2_aberto as bloco_2_aberto,
    dados.respostas_bloco_1 as respostas_bloco_1,
    dados.respostas_bloco_2 as respostas_bloco_2,
    dados.respostas_bloco_3 as respostas_bloco_3,
    dados.conceito_q1 as conceito_q1,
    dados.conceito_q2 as conceito_q2,
    dados.gabarito_bloco_1 as gabarito_bloco_1,
    dados.gabarito_bloco_2 as gabarito_bloco_2,
    dados.gabarito_bloco_3 as gabarito_bloco_3,
    dados.indicador_proficiencia as indicador_proficiencia,
    dados.indicador_prova_brasil as indicador_prova_brasil,
    dados.amostra as amostra,
    dados.estrato as estrato,
    dados.peso_escola as peso_escola,
    dados.peso_turma as peso_turma,
    dados.peso_aluno_turma as peso_aluno_turma,
    dados.peso_aluno as peso_aluno,
    dados.proficiencia as proficiencia,
    dados.erro_padrao as erro_padrao,
    dados.proficiencia_saeb as proficiencia_saeb,
    dados.erro_padrao_saeb as erro_padrao_saeb,
    dados.desempenho_aluno as desempenho_aluno,
    dados.preenchimento_questionario as preenchimento_questionario,
    dados.sexo as sexo,
    dados.raca_cor as raca_cor,
    dados.mes_nascimento as mes_nascimento,
    dados.ano_nascimento as ano_nascimento,
    dados.idade as idade,
    dados.faixa_etaria as faixa_etaria,
    dados.possui_necessidade_especial as possui_necessidade_especial,
    dados.estado_civil as estado_civil,
    dados.possui_filhos as possui_filhos,
    dados.com_quem_mora as com_quem_mora,
    dados.mora_mae as mora_mae,
    dados.mora_pai as mora_pai,
    dados.mora_irmaos as mora_irmaos,
    dados.mora_avos as mora_avos,
    dados.mora_conjuge as mora_conjuge,
    dados.mora_filhos as mora_filhos,
    dados.mora_outros_parentes as mora_outros_parentes,
    dados.mora_amigos as mora_amigos,
    dados.idioma_domicilio as idioma_domicilio,
    dados.quantidade_pessoas_domicilio as quantidade_pessoas_domicilio,
    dados.quantidade_pessoas_despesas_domicilio as quantidade_pessoas_despesas_domicilio,
    dados.situacao_economica as situacao_economica,
    dados.possui_trabalho as possui_trabalho,
    dados.turma_bolsa_escola as turma_bolsa_escola,
    dados.aluno_bolsa_escola as aluno_bolsa_escola,
    dados.indicador_inse as indicador_inse,
    dados.inse as inse,
    dados.nivel_inse as nivel_inse,
    dados.peso_inse as peso_inse,
    dados.possui_moradia_rua_urbanizada as possui_moradia_rua_urbanizada,
    dados.possui_agua_encanada as possui_agua_encanada,
    dados.possui_eletrecidade as possui_eletrecidade,
    dados.possui_eletrodomestico_sem_eletricidade as possui_eletrodomestico_sem_eletricidade,
    dados.possui_casa_dormitorio as possui_casa_dormitorio,
    dados.possui_casa_quarto_individual as possui_casa_quarto_individual,
    dados.possui_casa_cozinha as possui_casa_cozinha,
    dados.possui_casa_banheiro as possui_casa_banheiro,
    dados.possui_casa_sala as possui_casa_sala,
    dados.possui_automovel as possui_automovel,
    dados.possui_casa_garagem as possui_casa_garagem,
    dados.possui_geladeira as possui_geladeira,
    dados.possui_geladeira_freezer as possui_geladeira_freezer,
    dados.possui_freezer as possui_freezer,
    dados.possui_microondas as possui_microondas,
    dados.possui_maquina_lavar_roupa as possui_maquina_lavar_roupa,
    dados.possui_aspirador_po as possui_aspirador_po,
    dados.possui_radio as possui_radio,
    dados.possui_tv as possui_tv,
    dados.possui_tv_assinatura as possui_tv_assinatura,
    dados.possui_videocassete_dvd as possui_videocassete_dvd,
    dados.possui_internet as possui_internet,
    dados.possui_computador as possui_computador,
    dados.possui_computador_sem_internet as possui_computador_sem_internet,
    dados.possui_tablet as possui_tablet,
    dados.possui_telefone as possui_telefone,
    dados.possui_celular as possui_celular,
    dados.possui_escrivaninha as possui_escrivaninha,
    dados.possui_enciclopedia as possui_enciclopedia,
    dados.possui_atlas as possui_atlas,
    dados.possui_dicionario as possui_dicionario,
    dados.possui_calculadora as possui_calculadora,
    dados.possui_empregada_domestica as possui_empregada_domestica,
    dados.possui_empregada_domestica_cinco_dias as possui_empregada_domestica_cinco_dias,
    dados.escolaridade_mae as escolaridade_mae,
    dados.mae_sabe_ler_escrever as mae_sabe_ler_escrever,
    dados.mae_le as mae_le,
    dados.ocupacao_mae as ocupacao_mae,
    dados.escolaridade_pai as escolaridade_pai,
    dados.pai_sabe_ler_escrever as pai_sabe_ler_escrever,
    dados.pai_le as pai_le,
    dados.ocupacao_pai as ocupacao_pai,
    dados.pessoa_acompanha_vida_escolar as pessoa_acompanha_vida_escolar,
    dados.escolaridade_pessoa as escolaridade_pessoa,
    dados.responsaveis_conhecem_diretor as responsaveis_conhecem_diretor,
    dados.responsaveis_conhecem_professor as responsaveis_conhecem_professor,
    dados.responsaveis_conversam_professor_diretor as responsaveis_conversam_professor_diretor,
    dados.responsaveis_conversam_diretor as responsaveis_conversam_diretor,
    dados.responsaveis_conversam_professor as responsaveis_conversam_professor,
    dados.responsaveis_conhecem_amigo as responsaveis_conhecem_amigo,
    dados.responsaveis_conhecem_responsavel_amigo as responsaveis_conhecem_responsavel_amigo,
    dados.responsaveis_leem as responsaveis_leem,
    dados.responsaveis_almocam_jantam_contigo as responsaveis_almocam_jantam_contigo,
    dados.responsaveis_ouvem_musica_contigo as responsaveis_ouvem_musica_contigo,
    dados.responsaveis_conversam_livros_contigo as responsaveis_conversam_livros_contigo,
    dados.responsaveis_conversam_filmes_contigo as responsaveis_conversam_filmes_contigo,
    dados.responsaveis_conversam_programas_tv_contigo as responsaveis_conversam_programas_tv_contigo,
    dados.responsaveis_conversam_amigos as responsaveis_conversam_amigos,
    dados.responsaveis_conversam_amigos_escola as responsaveis_conversam_amigos_escola,
    dados.responsaveis_conversam_responsaveis_amigo as responsaveis_conversam_responsaveis_amigo,
    dados.responsaveis_conversam_outros_assuntos_contigo as responsaveis_conversam_outros_assuntos_contigo,
    dados.responsaveis_conversam_escola as responsaveis_conversam_escola,
    dados.responsaveis_conversam_boletim as responsaveis_conversam_boletim,
    dados.responsaveis_conversam_comportamento as responsaveis_conversam_comportamento,
    dados.responsaveis_cobram_realizacao_tarefa_casa as responsaveis_cobram_realizacao_tarefa_casa,
    dados.responsaveis_ajudam_realizacao_tarefa_casa as responsaveis_ajudam_realizacao_tarefa_casa,
    dados.responsaveis_incentivam_realizacao_licao_casa as responsaveis_incentivam_realizacao_licao_casa,
    dados.responsaveis_incentivam_estudos as responsaveis_incentivam_estudos,
    dados.responsaveis_incentivam_leitura as responsaveis_incentivam_leitura,
    dados.responsaveis_incentivam_comparecer_aulas as responsaveis_incentivam_comparecer_aulas,
    dados.responsaveis_incentivam_pontualidade as responsaveis_incentivam_pontualidade,
    dados.responsaveis_incentivam_boas_notas as responsaveis_incentivam_boas_notas,
    dados.responsaveis_comparecem_reuniao_pais as responsaveis_comparecem_reuniao_pais,
    dados.responsaveis_participam_festas_escola as responsaveis_participam_festas_escola,
    dados.responsaveis_participam_trabalho_voluntario as responsaveis_participam_trabalho_voluntario,
    dados.tempo_chegada_escola as tempo_chegada_escola,
    dados.forma_chegada_escola as forma_chegada_escola,
    dados.transporte_escolar as transporte_escolar,
    dados.inicio_estudos as inicio_estudos,
    dados.quantos_anos_primeiro_grau as quantos_anos_primeiro_grau,
    dados.quantos_anos_segundo_grau as quantos_anos_segundo_grau,
    dados.idade_entrada_escola as idade_entrada_escola,
    dados.quantidade_mudancas_escola as quantidade_mudancas_escola,
    dados.presenca_professor as presenca_professor,
    dados.supletivo_ef as supletivo_ef,
    dados.rede_ef as rede_ef,
    dados.reprovacao as reprovacao,
    dados.evasao_escolar_ate_final_ano as evasao_escolar_ate_final_ano,
    dados.evasao_escolar_temporaria as evasao_escolar_temporaria,
    dados.motivo_evasao_escolar as motivo_evasao_escolar,
    dados.faltas_aula as faltas_aula,
    dados.motivo_faltas as motivo_faltas,
    dados.desempenho_prejudicado_falta as desempenho_prejudicado_falta,
    dados.tempo_lazer as tempo_lazer,
    dados.tipo_programacao_tv as tipo_programacao_tv,
    dados.tempo_cursos as tempo_cursos,
    dados.tempo_trabalho_domestico as tempo_trabalho_domestico,
    dados.tempo_estudos as tempo_estudos,
    dados.quantidade_livros as quantidade_livros,
    dados.recebe_jornais as recebe_jornais,
    dados.recebe_revistas as recebe_revistas,
    dados.leitura_jornais as leitura_jornais,
    dados.leitura_noticias as leitura_noticias,
    dados.leitura_livros_geral as leitura_livros_geral,
    dados.leitura_literatura as leitura_literatura,
    dados.leitura_literatura_infantojuvenil as leitura_literatura_infantojuvenil,
    dados.leitura_historia_quadrinhos as leitura_historia_quadrinhos,
    dados.leitura_revistas_tematicas as leitura_revistas_tematicas,
    dados.leitura_revista_comportamento as leitura_revista_comportamento,
    dados.leitura_revistas_geral as leitura_revistas_geral,
    dados.leitura_internet as leitura_internet,
    dados.leitura_outros_materiais as leitura_outros_materiais,
    dados.frequenta_biblioteca as frequenta_biblioteca,
    dados.frequenta_cinema as frequenta_cinema,
    dados.frequenta_espetaculo_exposicao as frequenta_espetaculo_exposicao,
    dados.frequenta_teatro as frequenta_teatro,
    dados.frequenta_show as frequenta_show,
    dados.frequenta_festas_comunidade as frequenta_festas_comunidade,
    dados.participa_gremio_escolar as participa_gremio_escolar,
    dados.participa_associacao_desportiva as participa_associacao_desportiva,
    dados.participa_associacao_moradores as participa_associacao_moradores,
    dados.participa_sindicato as participa_sindicato,
    dados.participa_movimento_religioso as participa_movimento_religioso,
    dados.participa_partido_politico as participa_partido_politico,
    dados.participa_ong as participa_ong,
    dados.nao_participa as nao_participa,
    dados.participa_atividades_esporte as participa_atividades_esporte,
    dados.participa_atividades_artisticas as participa_atividades_artisticas,
    dados.participa_trabalho_solidario as participa_trabalho_solidario,
    dados.participa_reforco_escolar as participa_reforco_escolar,
    dados.participa_excursao_acampamento as participa_excursao_acampamento,
    dados.participa_festas as participa_festas,
    dados.curso_atividades_artisticas as curso_atividades_artisticas,
    dados.curso_reforco_escolar as curso_reforco_escolar,
    dados.curso_idioma_externo as curso_idioma_externo,
    dados.curso_informatica as curso_informatica,
    dados.curso_outros as curso_outros,
    dados.quando_nao_entende_materia as quando_nao_entende_materia,
    dados.gosta_estudar_disciplina as gosta_estudar_disciplina,
    dados.entendimento_ensino as entendimento_ensino,
    dados.disciplina_auxilia_compreensao as disciplina_auxilia_compreensao,
    dados.professor_disciplina as professor_disciplina,
    dados.faz_licao_casa as faz_licao_casa,
    dados.tempo_licao_casa as tempo_licao_casa,
    dados.fez_redacao as fez_redacao,
    dados.professor_leitura_livros_licao_casa as professor_leitura_livros_licao_casa,
    dados.correcao_licao_casa as correcao_licao_casa,
    dados.correcao_licao_casa_alunos as correcao_licao_casa_alunos,
    dados.consulta_jornais_revistas_licao_casa as consulta_jornais_revistas_licao_casa,
    dados.utiliza_computador_licao_casa as utiliza_computador_licao_casa,
    dados.utiliza_computador as utiliza_computador,
    dados.utiliza_computador_escola as utiliza_computador_escola,
    dados.utiliza_biblioteca_escola as utiliza_biblioteca_escola,
    dados.utiliza_biblioteca_externa as utiliza_biblioteca_externa,
    dados.existe_lugar_calmo_estudos as existe_lugar_calmo_estudos,
    dados.comparacao_colegas_disciplina as comparacao_colegas_disciplina,
    dados.boas_notas_disciplina as boas_notas_disciplina,
    dados.desempenho_disciplina as desempenho_disciplina,
    dados.professor_importa_voce_diz as professor_importa_voce_diz,
    dados.professor_conversa_avaliacao as professor_conversa_avaliacao,
    dados.professor_elogia_merecimento as professor_elogia_merecimento,
    dados.professor_ajuda_se_necessario as professor_ajuda_se_necessario,
    dados.professor_atende_prontamente as professor_atende_prontamente,
    dados.professor_esforca_aprendizado as professor_esforca_aprendizado,
    dados.professor_utiliza_espacos_externos as professor_utiliza_espacos_externos,
    dados.professor_espera_silencio as professor_espera_silencio,
    dados.professor_cobra as professor_cobra,
    dados.brigou_professor as brigou_professor,
    dados.turma_exclui as turma_exclui,
    dados.familia_avisada_falta as familia_avisada_falta,
    dados.alunos_desordeiros as alunos_desordeiros,
    dados.alunos_atentos as alunos_atentos,
    dados.alunos_obedientes as alunos_obedientes,
    dados.possui_amigos_sala as possui_amigos_sala,
    dados.estuda_habitualmente as estuda_habitualmente,
    dados.motivo_estar_escola as motivo_estar_escola,
    dados.utiliza_aprendizado_diariamente as utiliza_aprendizado_diariamente,
    dados.pandemia_equipamento_ensino_remoto as pandemia_equipamento_ensino_remoto,
    dados.pandemia_internet_ensino_remoto as pandemia_internet_ensino_remoto,
    dados.pandemia_facilidade_programas as pandemia_facilidade_programas,
    dados.pandemia_recebeu_material as pandemia_recebeu_material,
    dados.pandemia_auxilio_professor as pandemia_auxilio_professor,
    dados.pandemia_compreensao_conteudo as pandemia_compreensao_conteudo,
    dados.pandemia_ambiente_tranquilo as pandemia_ambiente_tranquilo,
    dados.pandemia_apoio_familia as pandemia_apoio_familia,
    dados.pandemia_apoio_colegas as pandemia_apoio_colegas,
    dados.pretensao_futura as pretensao_futura,
    dados.opiniao_teste as opiniao_teste,
    dados.opiniao_frase_1 as opiniao_frase_1,
    dados.opiniao_frase_2 as opiniao_frase_2,
    dados.opiniao_frase_3 as opiniao_frase_3
FROM `basedosdados.br_inep_saeb.aluno_ef_9ano` AS dados
WHERE dados.sigla_uf = 'PB' AND dados.ano = 2011;
"""

data2011 = bd.read_sql(query = query, billing_project_id = billing_id)
data2011.to_pickle('saeb_pb_2011.pkl')
# Out:
# Downloading: 100%|██████████| 91468/91468 [02:18<00:00, 660.74rows/s]

# %%
_oh[1].to_pickle('saeb_pb_2011.pkl')

# %%
import basedosdados as bd
from dotenv import load_dotenv
import os

load_dotenv()

billing_id = os.getenv("BILLING_ID")

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf as sigla_uf,
    dados.id_regiao as id_regiao,
    dados.id_municipio as id_municipio,
    dados.area as area,
    dados.mascara as mascara,
    dados.ano_mascara as ano_mascara,
    dados.id_escola as id_escola,
    dados.rede as rede,
    dados.escola_publica as escola_publica,
    dados.localizacao as localizacao,
    dados.id_turma as id_turma,
    dados.turno as turno,
    dados.serie as serie,
    dados.id_aluno as id_aluno,
    dados.situacao_censo as situacao_censo,
    dados.disciplina as disciplina,
    dados.preenchimento_caderno as preenchimento_caderno,
    dados.presenca as presenca,
    dados.caderno as caderno,
    dados.bloco_1 as bloco_1,
    dados.bloco_2 as bloco_2,
    dados.bloco_3 as bloco_3,
    dados.bloco_1_aberto as bloco_1_aberto,
    dados.bloco_2_aberto as bloco_2_aberto,
    dados.respostas_bloco_1 as respostas_bloco_1,
    dados.respostas_bloco_2 as respostas_bloco_2,
    dados.respostas_bloco_3 as respostas_bloco_3,
    dados.conceito_q1 as conceito_q1,
    dados.conceito_q2 as conceito_q2,
    dados.gabarito_bloco_1 as gabarito_bloco_1,
    dados.gabarito_bloco_2 as gabarito_bloco_2,
    dados.gabarito_bloco_3 as gabarito_bloco_3,
    dados.indicador_proficiencia as indicador_proficiencia,
    dados.indicador_prova_brasil as indicador_prova_brasil,
    dados.amostra as amostra,
    dados.estrato as estrato,
    dados.peso_escola as peso_escola,
    dados.peso_turma as peso_turma,
    dados.peso_aluno_turma as peso_aluno_turma,
    dados.peso_aluno as peso_aluno,
    dados.proficiencia as proficiencia,
    dados.erro_padrao as erro_padrao,
    dados.proficiencia_saeb as proficiencia_saeb,
    dados.erro_padrao_saeb as erro_padrao_saeb,
    dados.desempenho_aluno as desempenho_aluno,
    dados.preenchimento_questionario as preenchimento_questionario,
    dados.sexo as sexo,
    dados.raca_cor as raca_cor,
    dados.mes_nascimento as mes_nascimento,
    dados.ano_nascimento as ano_nascimento,
    dados.idade as idade,
    dados.faixa_etaria as faixa_etaria,
    dados.possui_necessidade_especial as possui_necessidade_especial,
    dados.estado_civil as estado_civil,
    dados.possui_filhos as possui_filhos,
    dados.com_quem_mora as com_quem_mora,
    dados.mora_mae as mora_mae,
    dados.mora_pai as mora_pai,
    dados.mora_irmaos as mora_irmaos,
    dados.mora_avos as mora_avos,
    dados.mora_conjuge as mora_conjuge,
    dados.mora_filhos as mora_filhos,
    dados.mora_outros_parentes as mora_outros_parentes,
    dados.mora_amigos as mora_amigos,
    dados.idioma_domicilio as idioma_domicilio,
    dados.quantidade_pessoas_domicilio as quantidade_pessoas_domicilio,
    dados.quantidade_pessoas_despesas_domicilio as quantidade_pessoas_despesas_domicilio,
    dados.situacao_economica as situacao_economica,
    dados.possui_trabalho as possui_trabalho,
    dados.turma_bolsa_escola as turma_bolsa_escola,
    dados.aluno_bolsa_escola as aluno_bolsa_escola,
    dados.indicador_inse as indicador_inse,
    dados.inse as inse,
    dados.nivel_inse as nivel_inse,
    dados.peso_inse as peso_inse,
    dados.possui_moradia_rua_urbanizada as possui_moradia_rua_urbanizada,
    dados.possui_agua_encanada as possui_agua_encanada,
    dados.possui_eletrecidade as possui_eletrecidade,
    dados.possui_eletrodomestico_sem_eletricidade as possui_eletrodomestico_sem_eletricidade,
    dados.possui_casa_dormitorio as possui_casa_dormitorio,
    dados.possui_casa_quarto_individual as possui_casa_quarto_individual,
    dados.possui_casa_cozinha as possui_casa_cozinha,
    dados.possui_casa_banheiro as possui_casa_banheiro,
    dados.possui_casa_sala as possui_casa_sala,
    dados.possui_automovel as possui_automovel,
    dados.possui_casa_garagem as possui_casa_garagem,
    dados.possui_geladeira as possui_geladeira,
    dados.possui_geladeira_freezer as possui_geladeira_freezer,
    dados.possui_freezer as possui_freezer,
    dados.possui_microondas as possui_microondas,
    dados.possui_maquina_lavar_roupa as possui_maquina_lavar_roupa,
    dados.possui_aspirador_po as possui_aspirador_po,
    dados.possui_radio as possui_radio,
    dados.possui_tv as possui_tv,
    dados.possui_tv_assinatura as possui_tv_assinatura,
    dados.possui_videocassete_dvd as possui_videocassete_dvd,
    dados.possui_internet as possui_internet,
    dados.possui_computador as possui_computador,
    dados.possui_computador_sem_internet as possui_computador_sem_internet,
    dados.possui_tablet as possui_tablet,
    dados.possui_telefone as possui_telefone,
    dados.possui_celular as possui_celular,
    dados.possui_escrivaninha as possui_escrivaninha,
    dados.possui_enciclopedia as possui_enciclopedia,
    dados.possui_atlas as possui_atlas,
    dados.possui_dicionario as possui_dicionario,
    dados.possui_calculadora as possui_calculadora,
    dados.possui_empregada_domestica as possui_empregada_domestica,
    dados.possui_empregada_domestica_cinco_dias as possui_empregada_domestica_cinco_dias,
    dados.escolaridade_mae as escolaridade_mae,
    dados.mae_sabe_ler_escrever as mae_sabe_ler_escrever,
    dados.mae_le as mae_le,
    dados.ocupacao_mae as ocupacao_mae,
    dados.escolaridade_pai as escolaridade_pai,
    dados.pai_sabe_ler_escrever as pai_sabe_ler_escrever,
    dados.pai_le as pai_le,
    dados.ocupacao_pai as ocupacao_pai,
    dados.pessoa_acompanha_vida_escolar as pessoa_acompanha_vida_escolar,
    dados.escolaridade_pessoa as escolaridade_pessoa,
    dados.responsaveis_conhecem_diretor as responsaveis_conhecem_diretor,
    dados.responsaveis_conhecem_professor as responsaveis_conhecem_professor,
    dados.responsaveis_conversam_professor_diretor as responsaveis_conversam_professor_diretor,
    dados.responsaveis_conversam_diretor as responsaveis_conversam_diretor,
    dados.responsaveis_conversam_professor as responsaveis_conversam_professor,
    dados.responsaveis_conhecem_amigo as responsaveis_conhecem_amigo,
    dados.responsaveis_conhecem_responsavel_amigo as responsaveis_conhecem_responsavel_amigo,
    dados.responsaveis_leem as responsaveis_leem,
    dados.responsaveis_almocam_jantam_contigo as responsaveis_almocam_jantam_contigo,
    dados.responsaveis_ouvem_musica_contigo as responsaveis_ouvem_musica_contigo,
    dados.responsaveis_conversam_livros_contigo as responsaveis_conversam_livros_contigo,
    dados.responsaveis_conversam_filmes_contigo as responsaveis_conversam_filmes_contigo,
    dados.responsaveis_conversam_programas_tv_contigo as responsaveis_conversam_programas_tv_contigo,
    dados.responsaveis_conversam_amigos as responsaveis_conversam_amigos,
    dados.responsaveis_conversam_amigos_escola as responsaveis_conversam_amigos_escola,
    dados.responsaveis_conversam_responsaveis_amigo as responsaveis_conversam_responsaveis_amigo,
    dados.responsaveis_conversam_outros_assuntos_contigo as responsaveis_conversam_outros_assuntos_contigo,
    dados.responsaveis_conversam_escola as responsaveis_conversam_escola,
    dados.responsaveis_conversam_boletim as responsaveis_conversam_boletim,
    dados.responsaveis_conversam_comportamento as responsaveis_conversam_comportamento,
    dados.responsaveis_cobram_realizacao_tarefa_casa as responsaveis_cobram_realizacao_tarefa_casa,
    dados.responsaveis_ajudam_realizacao_tarefa_casa as responsaveis_ajudam_realizacao_tarefa_casa,
    dados.responsaveis_incentivam_realizacao_licao_casa as responsaveis_incentivam_realizacao_licao_casa,
    dados.responsaveis_incentivam_estudos as responsaveis_incentivam_estudos,
    dados.responsaveis_incentivam_leitura as responsaveis_incentivam_leitura,
    dados.responsaveis_incentivam_comparecer_aulas as responsaveis_incentivam_comparecer_aulas,
    dados.responsaveis_incentivam_pontualidade as responsaveis_incentivam_pontualidade,
    dados.responsaveis_incentivam_boas_notas as responsaveis_incentivam_boas_notas,
    dados.responsaveis_comparecem_reuniao_pais as responsaveis_comparecem_reuniao_pais,
    dados.responsaveis_participam_festas_escola as responsaveis_participam_festas_escola,
    dados.responsaveis_participam_trabalho_voluntario as responsaveis_participam_trabalho_voluntario,
    dados.tempo_chegada_escola as tempo_chegada_escola,
    dados.forma_chegada_escola as forma_chegada_escola,
    dados.transporte_escolar as transporte_escolar,
    dados.inicio_estudos as inicio_estudos,
    dados.quantos_anos_primeiro_grau as quantos_anos_primeiro_grau,
    dados.quantos_anos_segundo_grau as quantos_anos_segundo_grau,
    dados.idade_entrada_escola as idade_entrada_escola,
    dados.quantidade_mudancas_escola as quantidade_mudancas_escola,
    dados.presenca_professor as presenca_professor,
    dados.supletivo_ef as supletivo_ef,
    dados.rede_ef as rede_ef,
    dados.reprovacao as reprovacao,
    dados.evasao_escolar_ate_final_ano as evasao_escolar_ate_final_ano,
    dados.evasao_escolar_temporaria as evasao_escolar_temporaria,
    dados.motivo_evasao_escolar as motivo_evasao_escolar,
    dados.faltas_aula as faltas_aula,
    dados.motivo_faltas as motivo_faltas,
    dados.desempenho_prejudicado_falta as desempenho_prejudicado_falta,
    dados.tempo_lazer as tempo_lazer,
    dados.tipo_programacao_tv as tipo_programacao_tv,
    dados.tempo_cursos as tempo_cursos,
    dados.tempo_trabalho_domestico as tempo_trabalho_domestico,
    dados.tempo_estudos as tempo_estudos,
    dados.quantidade_livros as quantidade_livros,
    dados.recebe_jornais as recebe_jornais,
    dados.recebe_revistas as recebe_revistas,
    dados.leitura_jornais as leitura_jornais,
    dados.leitura_noticias as leitura_noticias,
    dados.leitura_livros_geral as leitura_livros_geral,
    dados.leitura_literatura as leitura_literatura,
    dados.leitura_literatura_infantojuvenil as leitura_literatura_infantojuvenil,
    dados.leitura_historia_quadrinhos as leitura_historia_quadrinhos,
    dados.leitura_revistas_tematicas as leitura_revistas_tematicas,
    dados.leitura_revista_comportamento as leitura_revista_comportamento,
    dados.leitura_revistas_geral as leitura_revistas_geral,
    dados.leitura_internet as leitura_internet,
    dados.leitura_outros_materiais as leitura_outros_materiais,
    dados.frequenta_biblioteca as frequenta_biblioteca,
    dados.frequenta_cinema as frequenta_cinema,
    dados.frequenta_espetaculo_exposicao as frequenta_espetaculo_exposicao,
    dados.frequenta_teatro as frequenta_teatro,
    dados.frequenta_show as frequenta_show,
    dados.frequenta_festas_comunidade as frequenta_festas_comunidade,
    dados.participa_gremio_escolar as participa_gremio_escolar,
    dados.participa_associacao_desportiva as participa_associacao_desportiva,
    dados.participa_associacao_moradores as participa_associacao_moradores,
    dados.participa_sindicato as participa_sindicato,
    dados.participa_movimento_religioso as participa_movimento_religioso,
    dados.participa_partido_politico as participa_partido_politico,
    dados.participa_ong as participa_ong,
    dados.nao_participa as nao_participa,
    dados.participa_atividades_esporte as participa_atividades_esporte,
    dados.participa_atividades_artisticas as participa_atividades_artisticas,
    dados.participa_trabalho_solidario as participa_trabalho_solidario,
    dados.participa_reforco_escolar as participa_reforco_escolar,
    dados.participa_excursao_acampamento as participa_excursao_acampamento,
    dados.participa_festas as participa_festas,
    dados.curso_atividades_artisticas as curso_atividades_artisticas,
    dados.curso_reforco_escolar as curso_reforco_escolar,
    dados.curso_idioma_externo as curso_idioma_externo,
    dados.curso_informatica as curso_informatica,
    dados.curso_outros as curso_outros,
    dados.quando_nao_entende_materia as quando_nao_entende_materia,
    dados.gosta_estudar_disciplina as gosta_estudar_disciplina,
    dados.entendimento_ensino as entendimento_ensino,
    dados.disciplina_auxilia_compreensao as disciplina_auxilia_compreensao,
    dados.professor_disciplina as professor_disciplina,
    dados.faz_licao_casa as faz_licao_casa,
    dados.tempo_licao_casa as tempo_licao_casa,
    dados.fez_redacao as fez_redacao,
    dados.professor_leitura_livros_licao_casa as professor_leitura_livros_licao_casa,
    dados.correcao_licao_casa as correcao_licao_casa,
    dados.correcao_licao_casa_alunos as correcao_licao_casa_alunos,
    dados.consulta_jornais_revistas_licao_casa as consulta_jornais_revistas_licao_casa,
    dados.utiliza_computador_licao_casa as utiliza_computador_licao_casa,
    dados.utiliza_computador as utiliza_computador,
    dados.utiliza_computador_escola as utiliza_computador_escola,
    dados.utiliza_biblioteca_escola as utiliza_biblioteca_escola,
    dados.utiliza_biblioteca_externa as utiliza_biblioteca_externa,
    dados.existe_lugar_calmo_estudos as existe_lugar_calmo_estudos,
    dados.comparacao_colegas_disciplina as comparacao_colegas_disciplina,
    dados.boas_notas_disciplina as boas_notas_disciplina,
    dados.desempenho_disciplina as desempenho_disciplina,
    dados.professor_importa_voce_diz as professor_importa_voce_diz,
    dados.professor_conversa_avaliacao as professor_conversa_avaliacao,
    dados.professor_elogia_merecimento as professor_elogia_merecimento,
    dados.professor_ajuda_se_necessario as professor_ajuda_se_necessario,
    dados.professor_atende_prontamente as professor_atende_prontamente,
    dados.professor_esforca_aprendizado as professor_esforca_aprendizado,
    dados.professor_utiliza_espacos_externos as professor_utiliza_espacos_externos,
    dados.professor_espera_silencio as professor_espera_silencio,
    dados.professor_cobra as professor_cobra,
    dados.brigou_professor as brigou_professor,
    dados.turma_exclui as turma_exclui,
    dados.familia_avisada_falta as familia_avisada_falta,
    dados.alunos_desordeiros as alunos_desordeiros,
    dados.alunos_atentos as alunos_atentos,
    dados.alunos_obedientes as alunos_obedientes,
    dados.possui_amigos_sala as possui_amigos_sala,
    dados.estuda_habitualmente as estuda_habitualmente,
    dados.motivo_estar_escola as motivo_estar_escola,
    dados.utiliza_aprendizado_diariamente as utiliza_aprendizado_diariamente,
    dados.pandemia_equipamento_ensino_remoto as pandemia_equipamento_ensino_remoto,
    dados.pandemia_internet_ensino_remoto as pandemia_internet_ensino_remoto,
    dados.pandemia_facilidade_programas as pandemia_facilidade_programas,
    dados.pandemia_recebeu_material as pandemia_recebeu_material,
    dados.pandemia_auxilio_professor as pandemia_auxilio_professor,
    dados.pandemia_compreensao_conteudo as pandemia_compreensao_conteudo,
    dados.pandemia_ambiente_tranquilo as pandemia_ambiente_tranquilo,
    dados.pandemia_apoio_familia as pandemia_apoio_familia,
    dados.pandemia_apoio_colegas as pandemia_apoio_colegas,
    dados.pretensao_futura as pretensao_futura,
    dados.opiniao_teste as opiniao_teste,
    dados.opiniao_frase_1 as opiniao_frase_1,
    dados.opiniao_frase_2 as opiniao_frase_2,
    dados.opiniao_frase_3 as opiniao_frase_3
FROM `basedosdados.br_inep_saeb.aluno_ef_9ano` AS dados
WHERE dados.sigla_uf = 'PB' AND dados.ano = 2009;
"""

data2009 = bd.read_sql(query = query, billing_project_id = billing_id)

data2009.to_pickle('saeb_pb_2009.pkl')
# Out:
# Downloading: 100%|██████████| 114976/114976 [02:42<00:00, 705.75rows/s]

# %%
_oh[1].to_pickle('saeb_pb_2009.pkl')

# %%
import basedosdados as bd
from dotenv import load_dotenv
import os

load_dotenv()

billing_id = os.getenv("BILLING_ID")

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf as sigla_uf,
    dados.id_regiao as id_regiao,
    dados.id_municipio as id_municipio,
    dados.area as area,
    dados.mascara as mascara,
    dados.ano_mascara as ano_mascara,
    dados.id_escola as id_escola,
    dados.rede as rede,
    dados.escola_publica as escola_publica,
    dados.localizacao as localizacao,
    dados.id_turma as id_turma,
    dados.turno as turno,
    dados.serie as serie,
    dados.id_aluno as id_aluno,
    dados.situacao_censo as situacao_censo,
    dados.disciplina as disciplina,
    dados.preenchimento_caderno as preenchimento_caderno,
    dados.presenca as presenca,
    dados.caderno as caderno,
    dados.bloco_1 as bloco_1,
    dados.bloco_2 as bloco_2,
    dados.bloco_3 as bloco_3,
    dados.bloco_1_aberto as bloco_1_aberto,
    dados.bloco_2_aberto as bloco_2_aberto,
    dados.respostas_bloco_1 as respostas_bloco_1,
    dados.respostas_bloco_2 as respostas_bloco_2,
    dados.respostas_bloco_3 as respostas_bloco_3,
    dados.conceito_q1 as conceito_q1,
    dados.conceito_q2 as conceito_q2,
    dados.gabarito_bloco_1 as gabarito_bloco_1,
    dados.gabarito_bloco_2 as gabarito_bloco_2,
    dados.gabarito_bloco_3 as gabarito_bloco_3,
    dados.indicador_proficiencia as indicador_proficiencia,
    dados.indicador_prova_brasil as indicador_prova_brasil,
    dados.amostra as amostra,
    dados.estrato as estrato,
    dados.peso_escola as peso_escola,
    dados.peso_turma as peso_turma,
    dados.peso_aluno_turma as peso_aluno_turma,
    dados.peso_aluno as peso_aluno,
    dados.proficiencia as proficiencia,
    dados.erro_padrao as erro_padrao,
    dados.proficiencia_saeb as proficiencia_saeb,
    dados.erro_padrao_saeb as erro_padrao_saeb,
    dados.desempenho_aluno as desempenho_aluno,
    dados.preenchimento_questionario as preenchimento_questionario,
    dados.sexo as sexo,
    dados.raca_cor as raca_cor,
    dados.mes_nascimento as mes_nascimento,
    dados.ano_nascimento as ano_nascimento,
    dados.idade as idade,
    dados.faixa_etaria as faixa_etaria,
    dados.possui_necessidade_especial as possui_necessidade_especial,
    dados.estado_civil as estado_civil,
    dados.possui_filhos as possui_filhos,
    dados.com_quem_mora as com_quem_mora,
    dados.mora_mae as mora_mae,
    dados.mora_pai as mora_pai,
    dados.mora_irmaos as mora_irmaos,
    dados.mora_avos as mora_avos,
    dados.mora_conjuge as mora_conjuge,
    dados.mora_filhos as mora_filhos,
    dados.mora_outros_parentes as mora_outros_parentes,
    dados.mora_amigos as mora_amigos,
    dados.idioma_domicilio as idioma_domicilio,
    dados.quantidade_pessoas_domicilio as quantidade_pessoas_domicilio,
    dados.quantidade_pessoas_despesas_domicilio as quantidade_pessoas_despesas_domicilio,
    dados.situacao_economica as situacao_economica,
    dados.possui_trabalho as possui_trabalho,
    dados.turma_bolsa_escola as turma_bolsa_escola,
    dados.aluno_bolsa_escola as aluno_bolsa_escola,
    dados.indicador_inse as indicador_inse,
    dados.inse as inse,
    dados.nivel_inse as nivel_inse,
    dados.peso_inse as peso_inse,
    dados.possui_moradia_rua_urbanizada as possui_moradia_rua_urbanizada,
    dados.possui_agua_encanada as possui_agua_encanada,
    dados.possui_eletrecidade as possui_eletrecidade,
    dados.possui_eletrodomestico_sem_eletricidade as possui_eletrodomestico_sem_eletricidade,
    dados.possui_casa_dormitorio as possui_casa_dormitorio,
    dados.possui_casa_quarto_individual as possui_casa_quarto_individual,
    dados.possui_casa_cozinha as possui_casa_cozinha,
    dados.possui_casa_banheiro as possui_casa_banheiro,
    dados.possui_casa_sala as possui_casa_sala,
    dados.possui_automovel as possui_automovel,
    dados.possui_casa_garagem as possui_casa_garagem,
    dados.possui_geladeira as possui_geladeira,
    dados.possui_geladeira_freezer as possui_geladeira_freezer,
    dados.possui_freezer as possui_freezer,
    dados.possui_microondas as possui_microondas,
    dados.possui_maquina_lavar_roupa as possui_maquina_lavar_roupa,
    dados.possui_aspirador_po as possui_aspirador_po,
    dados.possui_radio as possui_radio,
    dados.possui_tv as possui_tv,
    dados.possui_tv_assinatura as possui_tv_assinatura,
    dados.possui_videocassete_dvd as possui_videocassete_dvd,
    dados.possui_internet as possui_internet,
    dados.possui_computador as possui_computador,
    dados.possui_computador_sem_internet as possui_computador_sem_internet,
    dados.possui_tablet as possui_tablet,
    dados.possui_telefone as possui_telefone,
    dados.possui_celular as possui_celular,
    dados.possui_escrivaninha as possui_escrivaninha,
    dados.possui_enciclopedia as possui_enciclopedia,
    dados.possui_atlas as possui_atlas,
    dados.possui_dicionario as possui_dicionario,
    dados.possui_calculadora as possui_calculadora,
    dados.possui_empregada_domestica as possui_empregada_domestica,
    dados.possui_empregada_domestica_cinco_dias as possui_empregada_domestica_cinco_dias,
    dados.escolaridade_mae as escolaridade_mae,
    dados.mae_sabe_ler_escrever as mae_sabe_ler_escrever,
    dados.mae_le as mae_le,
    dados.ocupacao_mae as ocupacao_mae,
    dados.escolaridade_pai as escolaridade_pai,
    dados.pai_sabe_ler_escrever as pai_sabe_ler_escrever,
    dados.pai_le as pai_le,
    dados.ocupacao_pai as ocupacao_pai,
    dados.pessoa_acompanha_vida_escolar as pessoa_acompanha_vida_escolar,
    dados.escolaridade_pessoa as escolaridade_pessoa,
    dados.responsaveis_conhecem_diretor as responsaveis_conhecem_diretor,
    dados.responsaveis_conhecem_professor as responsaveis_conhecem_professor,
    dados.responsaveis_conversam_professor_diretor as responsaveis_conversam_professor_diretor,
    dados.responsaveis_conversam_diretor as responsaveis_conversam_diretor,
    dados.responsaveis_conversam_professor as responsaveis_conversam_professor,
    dados.responsaveis_conhecem_amigo as responsaveis_conhecem_amigo,
    dados.responsaveis_conhecem_responsavel_amigo as responsaveis_conhecem_responsavel_amigo,
    dados.responsaveis_leem as responsaveis_leem,
    dados.responsaveis_almocam_jantam_contigo as responsaveis_almocam_jantam_contigo,
    dados.responsaveis_ouvem_musica_contigo as responsaveis_ouvem_musica_contigo,
    dados.responsaveis_conversam_livros_contigo as responsaveis_conversam_livros_contigo,
    dados.responsaveis_conversam_filmes_contigo as responsaveis_conversam_filmes_contigo,
    dados.responsaveis_conversam_programas_tv_contigo as responsaveis_conversam_programas_tv_contigo,
    dados.responsaveis_conversam_amigos as responsaveis_conversam_amigos,
    dados.responsaveis_conversam_amigos_escola as responsaveis_conversam_amigos_escola,
    dados.responsaveis_conversam_responsaveis_amigo as responsaveis_conversam_responsaveis_amigo,
    dados.responsaveis_conversam_outros_assuntos_contigo as responsaveis_conversam_outros_assuntos_contigo,
    dados.responsaveis_conversam_escola as responsaveis_conversam_escola,
    dados.responsaveis_conversam_boletim as responsaveis_conversam_boletim,
    dados.responsaveis_conversam_comportamento as responsaveis_conversam_comportamento,
    dados.responsaveis_cobram_realizacao_tarefa_casa as responsaveis_cobram_realizacao_tarefa_casa,
    dados.responsaveis_ajudam_realizacao_tarefa_casa as responsaveis_ajudam_realizacao_tarefa_casa,
    dados.responsaveis_incentivam_realizacao_licao_casa as responsaveis_incentivam_realizacao_licao_casa,
    dados.responsaveis_incentivam_estudos as responsaveis_incentivam_estudos,
    dados.responsaveis_incentivam_leitura as responsaveis_incentivam_leitura,
    dados.responsaveis_incentivam_comparecer_aulas as responsaveis_incentivam_comparecer_aulas,
    dados.responsaveis_incentivam_pontualidade as responsaveis_incentivam_pontualidade,
    dados.responsaveis_incentivam_boas_notas as responsaveis_incentivam_boas_notas,
    dados.responsaveis_comparecem_reuniao_pais as responsaveis_comparecem_reuniao_pais,
    dados.responsaveis_participam_festas_escola as responsaveis_participam_festas_escola,
    dados.responsaveis_participam_trabalho_voluntario as responsaveis_participam_trabalho_voluntario,
    dados.tempo_chegada_escola as tempo_chegada_escola,
    dados.forma_chegada_escola as forma_chegada_escola,
    dados.transporte_escolar as transporte_escolar,
    dados.inicio_estudos as inicio_estudos,
    dados.quantos_anos_primeiro_grau as quantos_anos_primeiro_grau,
    dados.quantos_anos_segundo_grau as quantos_anos_segundo_grau,
    dados.idade_entrada_escola as idade_entrada_escola,
    dados.quantidade_mudancas_escola as quantidade_mudancas_escola,
    dados.presenca_professor as presenca_professor,
    dados.supletivo_ef as supletivo_ef,
    dados.rede_ef as rede_ef,
    dados.reprovacao as reprovacao,
    dados.evasao_escolar_ate_final_ano as evasao_escolar_ate_final_ano,
    dados.evasao_escolar_temporaria as evasao_escolar_temporaria,
    dados.motivo_evasao_escolar as motivo_evasao_escolar,
    dados.faltas_aula as faltas_aula,
    dados.motivo_faltas as motivo_faltas,
    dados.desempenho_prejudicado_falta as desempenho_prejudicado_falta,
    dados.tempo_lazer as tempo_lazer,
    dados.tipo_programacao_tv as tipo_programacao_tv,
    dados.tempo_cursos as tempo_cursos,
    dados.tempo_trabalho_domestico as tempo_trabalho_domestico,
    dados.tempo_estudos as tempo_estudos,
    dados.quantidade_livros as quantidade_livros,
    dados.recebe_jornais as recebe_jornais,
    dados.recebe_revistas as recebe_revistas,
    dados.leitura_jornais as leitura_jornais,
    dados.leitura_noticias as leitura_noticias,
    dados.leitura_livros_geral as leitura_livros_geral,
    dados.leitura_literatura as leitura_literatura,
    dados.leitura_literatura_infantojuvenil as leitura_literatura_infantojuvenil,
    dados.leitura_historia_quadrinhos as leitura_historia_quadrinhos,
    dados.leitura_revistas_tematicas as leitura_revistas_tematicas,
    dados.leitura_revista_comportamento as leitura_revista_comportamento,
    dados.leitura_revistas_geral as leitura_revistas_geral,
    dados.leitura_internet as leitura_internet,
    dados.leitura_outros_materiais as leitura_outros_materiais,
    dados.frequenta_biblioteca as frequenta_biblioteca,
    dados.frequenta_cinema as frequenta_cinema,
    dados.frequenta_espetaculo_exposicao as frequenta_espetaculo_exposicao,
    dados.frequenta_teatro as frequenta_teatro,
    dados.frequenta_show as frequenta_show,
    dados.frequenta_festas_comunidade as frequenta_festas_comunidade,
    dados.participa_gremio_escolar as participa_gremio_escolar,
    dados.participa_associacao_desportiva as participa_associacao_desportiva,
    dados.participa_associacao_moradores as participa_associacao_moradores,
    dados.participa_sindicato as participa_sindicato,
    dados.participa_movimento_religioso as participa_movimento_religioso,
    dados.participa_partido_politico as participa_partido_politico,
    dados.participa_ong as participa_ong,
    dados.nao_participa as nao_participa,
    dados.participa_atividades_esporte as participa_atividades_esporte,
    dados.participa_atividades_artisticas as participa_atividades_artisticas,
    dados.participa_trabalho_solidario as participa_trabalho_solidario,
    dados.participa_reforco_escolar as participa_reforco_escolar,
    dados.participa_excursao_acampamento as participa_excursao_acampamento,
    dados.participa_festas as participa_festas,
    dados.curso_atividades_artisticas as curso_atividades_artisticas,
    dados.curso_reforco_escolar as curso_reforco_escolar,
    dados.curso_idioma_externo as curso_idioma_externo,
    dados.curso_informatica as curso_informatica,
    dados.curso_outros as curso_outros,
    dados.quando_nao_entende_materia as quando_nao_entende_materia,
    dados.gosta_estudar_disciplina as gosta_estudar_disciplina,
    dados.entendimento_ensino as entendimento_ensino,
    dados.disciplina_auxilia_compreensao as disciplina_auxilia_compreensao,
    dados.professor_disciplina as professor_disciplina,
    dados.faz_licao_casa as faz_licao_casa,
    dados.tempo_licao_casa as tempo_licao_casa,
    dados.fez_redacao as fez_redacao,
    dados.professor_leitura_livros_licao_casa as professor_leitura_livros_licao_casa,
    dados.correcao_licao_casa as correcao_licao_casa,
    dados.correcao_licao_casa_alunos as correcao_licao_casa_alunos,
    dados.consulta_jornais_revistas_licao_casa as consulta_jornais_revistas_licao_casa,
    dados.utiliza_computador_licao_casa as utiliza_computador_licao_casa,
    dados.utiliza_computador as utiliza_computador,
    dados.utiliza_computador_escola as utiliza_computador_escola,
    dados.utiliza_biblioteca_escola as utiliza_biblioteca_escola,
    dados.utiliza_biblioteca_externa as utiliza_biblioteca_externa,
    dados.existe_lugar_calmo_estudos as existe_lugar_calmo_estudos,
    dados.comparacao_colegas_disciplina as comparacao_colegas_disciplina,
    dados.boas_notas_disciplina as boas_notas_disciplina,
    dados.desempenho_disciplina as desempenho_disciplina,
    dados.professor_importa_voce_diz as professor_importa_voce_diz,
    dados.professor_conversa_avaliacao as professor_conversa_avaliacao,
    dados.professor_elogia_merecimento as professor_elogia_merecimento,
    dados.professor_ajuda_se_necessario as professor_ajuda_se_necessario,
    dados.professor_atende_prontamente as professor_atende_prontamente,
    dados.professor_esforca_aprendizado as professor_esforca_aprendizado,
    dados.professor_utiliza_espacos_externos as professor_utiliza_espacos_externos,
    dados.professor_espera_silencio as professor_espera_silencio,
    dados.professor_cobra as professor_cobra,
    dados.brigou_professor as brigou_professor,
    dados.turma_exclui as turma_exclui,
    dados.familia_avisada_falta as familia_avisada_falta,
    dados.alunos_desordeiros as alunos_desordeiros,
    dados.alunos_atentos as alunos_atentos,
    dados.alunos_obedientes as alunos_obedientes,
    dados.possui_amigos_sala as possui_amigos_sala,
    dados.estuda_habitualmente as estuda_habitualmente,
    dados.motivo_estar_escola as motivo_estar_escola,
    dados.utiliza_aprendizado_diariamente as utiliza_aprendizado_diariamente,
    dados.pandemia_equipamento_ensino_remoto as pandemia_equipamento_ensino_remoto,
    dados.pandemia_internet_ensino_remoto as pandemia_internet_ensino_remoto,
    dados.pandemia_facilidade_programas as pandemia_facilidade_programas,
    dados.pandemia_recebeu_material as pandemia_recebeu_material,
    dados.pandemia_auxilio_professor as pandemia_auxilio_professor,
    dados.pandemia_compreensao_conteudo as pandemia_compreensao_conteudo,
    dados.pandemia_ambiente_tranquilo as pandemia_ambiente_tranquilo,
    dados.pandemia_apoio_familia as pandemia_apoio_familia,
    dados.pandemia_apoio_colegas as pandemia_apoio_colegas,
    dados.pretensao_futura as pretensao_futura,
    dados.opiniao_teste as opiniao_teste,
    dados.opiniao_frase_1 as opiniao_frase_1,
    dados.opiniao_frase_2 as opiniao_frase_2,
    dados.opiniao_frase_3 as opiniao_frase_3
FROM `basedosdados.br_inep_saeb.aluno_ef_9ano` AS dados
WHERE dados.sigla_uf = 'PB' AND dados.ano = 2007;
"""

data2007 = bd.read_sql(query = query, billing_project_id = billing_id)
# Out:
# Downloading: 100%|██████████| 62880/62880 [01:32<00:00, 680.11rows/s]

# %%
data2007.to_pickle('saeb_pb_2007.pkl')
